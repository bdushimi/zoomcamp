# %%
#Installing necessary packages
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: mlflow in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.1.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: hyperopt in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.2.7)
# Requirement already satisfied: xgboost in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.0.3)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (8.1.7)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (5.3.3)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (7.1.0)
# Requirement already satisfied: entrypoints<1 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.1.37)
# Requirement already satisfied: graphene<4 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: numpy<2 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.24.0)
# Requirement already satisfied: packaging<25 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (14.0.2)
# Requirement already satisfied: pytz<2025 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: scipy<2 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (1.11.4)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (2.0.25)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: gunicorn<23 in /opt/anaconda3/lib/python3.11/site-packages (from mlflow->-r requirements.txt (line 1)) (22.0.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from hyperopt->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /opt/anaconda3/lib/python3.11/site-packages (from hyperopt->-r requirements.txt (line 5)) (3.1)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.11/site-packages (from hyperopt->-r requirements.txt (line 5)) (0.18.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from hyperopt->-r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: py4j in /opt/anaconda3/lib/python3.11/site-packages (from hyperopt->-r requirements.txt (line 5)) (0.10.9.7)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /opt/anaconda3/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow->-r requirements.txt (line 1)) (2.0.7)
# Requirement already satisfied: Werkzeug>=2.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from Flask<4->mlflow->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow->-r requirements.txt (line 1)) (4.0.7)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow->-r requirements.txt (line 1)) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /opt/anaconda3/lib/python3.11/site-packages (from graphene<4->mlflow->-r requirements.txt (line 1)) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow->-r requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from Jinja2<4,>=2.11->mlflow->-r requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib<4->mlflow->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.0.0->mlflow->-r requirements.txt (line 1)) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /opt/anaconda3/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow->-r requirements.txt (line 1)) (0.45b0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow->-r requirements.txt (line 1)) (2024.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/anaconda3/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow->-r requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow->-r requirements.txt (line 1)) (4.0.0)

# %%
# Q1. Install MLflow
# What's the version that you have?
# !mlflow --version
# Out:
# mlflow, version 2.13.0

# %%
# Q2. Download and preprocess the data
# How many files were saved to OUTPUT_FOLDER?
# !python preprocess_data.py --raw_data_path ./data --dest_path ./output 
# !ls -1 ./output | wc -l
# Out:
#        4

# %%
# Q3. Train a model with autolog
# What is the value of the min_samples_split parameter
# !python train.py  --data_path ./output

# Answer : min_samples_split 2
# Out:
# 2024/06/10 14:55:42 INFO mlflow.tracking.fluent: Experiment with name 'homework-2-nyc-taxi-experiments' does not exist. Creating a new experiment.
# 2024/06/10 14:55:43 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/06/10 14:55:43 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/06/10 14:55:52 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/anaconda3/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
# Q4. Launch the tracking server locally
# In addition to backend-store-uri, what else do you need to pass to properly configure the server?
! mlflow ui --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./artifacts
# Out:
# [2024-05-30 10:43:44 +0200] [12069] [INFO] Starting gunicorn 22.0.0
# [2024-05-30 10:43:44 +0200] [12069] [INFO] Listening at: http://127.0.0.1:5000 (12069)
# [2024-05-30 10:43:44 +0200] [12069] [INFO] Using worker: sync
# [2024-05-30 10:43:44 +0200] [12070] [INFO] Booting worker with pid: 12070
# [2024-05-30 10:43:44 +0200] [12071] [INFO] Booting worker with pid: 12071
# [2024-05-30 10:43:44 +0200] [12072] [INFO] Booting worker with pid: 12072
# [2024-05-30 10:43:44 +0200] [12073] [INFO] Booting worker with pid: 12073
# ^C
# [2024-05-30 12:25:52 +0200] [12069] [INFO] Handling signal: int
# [2024-05-30 12:25:52 +0200] [12070] [INFO] Worker exiting (pid: 12070)
# [2024-05-30 12:25:52 +0200] [12072] [INFO] Worker exiting (pid: 12072)
# [2024-05-30 12:25:52 +0200] [12071] [INFO] Worker exiting (pid: 12071)
# [2024-05-30 12:25:52 +0200] [12073] [INFO] Worker exiting (pid: 12073)

# %%
# Q5. Tune model hyperparameters
# What's the best validation RMSE that you got?
# !python register_model.py
# Out:
# 2024/05/30 12:26:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/30 12:26:22 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/opt/anaconda3/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# 2024/05/30 12:26:24 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/30 12:26:32 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/30 12:26:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/30 12:26:44 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# Best Run ID: f4f1d2e7da7449a0829cba52189977eb
# Best RMSE: 5.567408012462019
# Model URI: runs:/f4f1d2e7da7449a0829cba52189977eb/model
# Registered model 'RandomForestRegressor' already exists. Creating a new version of this model...
# 2024/05/30 12:26:50 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: RandomForestRegressor, version 2
# Created version '2' of model 'RandomForestRegressor'.
# Model registered with name: RandomForestRegressor and version: 2
